# %% [markdown]
# change 1

# %% [markdown]
# change 2

# %%
class Graph(object):
    """
    class of graph
    """
    
    def __init__(self):
        """
        V- множество вершин
        D - множество вершин, с возможностью их сортировки по степени
        colors - нужен только для покраски по вершинам
        """
        self.V = {}
        self.D = [] 
        self._D_sorted = False
        self.used_colors = set()
        self.coloring = dict()

    def add_edge(self,v1,v2):
        """
        add pair of vertexes to V
        add each other to neigbours
        """
        self._add_vertex_to_neighbours(v1,v2)
        self._add_vertex_to_neighbours(v2,v1)
        
        return
    
    def add_vertex(self,v1):
        """
        add one vertex to V
        """
        
        if v1 in self.V: # если вершина есть в множестве, то все ок. Ее не надо добавлять
                         # МБ надо обновить ее степень?
#             v1.update_degree = len(self.neighbours(v1))
#             self.V[v1]['degree'] = self.degree(v1)
#             D[self.V[v1]['D_index'] ] = self.V[v1]['degree']
            print('vertex already in graph.Vertexes')
            
            return
        else:
            self.V[v1] = {}
            self.V[v1]['name'] = v1
            self.V[v1]['neighbours'] = set()
            self.V[v1]['degree'] = 0
#             self.V[v1]['degree_position'] = 0
            self.D.append(self.V[v1])
#             self.V[v1]['D_index'] = len(self.D) - 1
            self._D_sorted = False
#             self.V[v1]['color'] = None
#             self.V[v1]['neigbour_colors'] = set()
            
            return
    
            
    def _add_vertex_to_neighbours(self,v1, v2):
        """
        add vertex v2 to neigbours of vertex v1
        """
        if v1 not in self.V:
            self.add_vertex(v1)
        if v2 in self.V[v1]['neighbours']:
            print('vertex already in neighbours')
            return
        self.V[v1]['neighbours'].add(v2)
        self.V[v1]['degree'] += 1
        self._D_sorted = False

        return
    
    def neighbours(self,v1):
        """
        print all neigbour names of chosed vertex
        """
        if v1 in self.V:
            return self.V[v1]['neighbours']
        else:
            print("no such vertex in graph")
            return None 
        
    def is_neighbour(self,vertex_name,neighbour_name):
        """
        vetrex - vertex name
        neighbout - neighbour name
        True if neighbour
        False if not neighbour
        """
        if neighbour_name in self.V[vertex_name]['neighbours']:
            return True
        return False
    
    
    def sort_vertex_by_degree_old(self):
        """
        sort vertexes: big degree is first
        """
        # добавить маркер сортер для массива Д для того, чтобы не сортировать сортированный Д
        if self._D_sorted :
            return
        #сортировка вставками по
        
        for i in range(len(self.D)-2,-1,-1):
            j = i
            while j <= len(self.D)-2 and self.D[j]['degree'] < self.D[j+1]['degree']:
#                 print(B,B[j],B[j+1],j)
                self.D[j],self.D[j+1] = self.D[j+1],self.D[j]
                j += 1
                #print('end',B,B[j],B[j+1],j)
    #                 print(A)
        
        
#         for i in range(len(self.D)):
#             self.D[i]['D_index'] = i
        self._D_sorted = True
        
        return
        
    def sort_vertex_by_degree(self):
        """
        sort vertexes: big degree is first
        """
        # добавить маркер сортер для массива Д для того, чтобы не сортировать сортированный Д
        if self._D_sorted :
            return
        self.D.sort(key= lambda input: input['degree'])
        self._D_sorted = True
        return

        
        
#     def number_by_degree(self,v1):
#         """
#         number in D, sorted by degree
#         """
#         self.sort_vertex_by_degree()
#         return self.V[v1]['D_index'] +1
    
        
    
    def degree(self,v1):
        """
        return degree of chosen vertex
        """
        if v1 in self.V:
            return len(self.V[v1]['neighbours'])
        else:
            return None
        
    def neighbour_max_degree(self,v1):
        """
        if vertex have neighbours - return neighbour with maximum degree
        if vertex don't have neighbours - return None
        """
        if len ( self.V[v1]['neighbours'] ) == 0:
            return None
        neighbour_max_degree_name = self.V[v1]['neighbours'].pop() # random vervex from neighbours 
        self.V[v1]['neighbours'].union(self.V[v1]['neighbours'], {neighbour_max_degree_name}) #back poped vertex back to neighbours
        max_degree = self.V[neighbour_max_degree_name]['degree']
            
        for neighbour in self.V[v1]['neighbours']:
            if self.V[neighbour]['degree'] > max_degree:
                max_degree = self.V[neighbour]['degree']
                neighbour_max_degree = self.V[neighbour]
        return neighbour_max_degree
    
    def vertex_max_degree(self):
        self.sort_vertex_by_degree()
        return self.D[0]
    
    
    

        
            
    
    def clear_coloring(self):
        self.used_colors = set()
        self.coloring = dict()

        
    def recolor(self):
        """
        Использовать с candidates при ветвлении
        т.к в первоначальной окраске слишком много цветов
        скорее всего стоит красить не каждое ветвление, а мб только в начале
        """
    #     print('***recolor***')
        max_color = -1
        self.coloring = dict()
        for vertex_name in self.V:
            self.coloring[vertex_name] = None
        self.used_colors = dict()
        for vertex_name in self.V:
#             print('vertex_name',vertex_name)
#             print('used_Colors',self.used_colors)
            avalible_colors = set(self.used_colors.keys() )
            for neighbour_name in g.V[vertex_name]['neighbours']:
#                 print('N',neighbour_name, self.coloring[neighbour_name] ,)
                avalible_colors -= {self.coloring[neighbour_name]}
                if len( avalible_colors ) == 0:
                    break
            if len( avalible_colors ) == 0:
                max_color += 1 # color is index in candidates_coloring
                self.used_colors[max_color] = set()
                self.used_colors[max_color].add(vertex_name)
                self.coloring[vertex_name] = max_color

#             print('avalible_colors',avalible_colors)
            if len( avalible_colors ) != 0:
                for avalible_color in avalible_colors:
                    rand_avalible_color = avalible_color
                    break
                self.used_colors[rand_avalible_color].add(vertex_name)
                self.coloring[vertex_name] = rand_avalible_color
#             print('chosen_Color',self.coloring[vertex_name])
#         return used_colors,candidates_coloring

    def recolor_by_degree(self):
        """
        Использовать с candidates при ветвлении
        т.к в первоначальной окраске слишком много цветов
        скорее всего стоит красить не каждое ветвление, а мб только в начале
        """
    #     print('***recolor***')    
        self.sort_vertex_by_degree()
        max_color = -1
        self.coloring = dict()
        for vertex_name in self.V:
            self.coloring[vertex_name] = None
        self.used_colors = dict()
        for vertex in self.D:
            vertex_name = vertex['name']
#             print('vertex_name',vertex_name)
#             print('used_Colors',self.used_colors)
            avalible_colors = set(self.used_colors.keys() )
            for neighbour_name in g.V[vertex_name]['neighbours']:
#                 print('N',neighbour_name, self.coloring[neighbour_name] ,)
                avalible_colors -= {self.coloring[neighbour_name]}
                if len( avalible_colors ) == 0:
                    break
            if len( avalible_colors ) == 0:
                max_color += 1 # color is index in candidates_coloring
                self.used_colors[max_color] = set()
                self.used_colors[max_color].add(vertex_name)
                self.coloring[vertex_name] = max_color

#             print('avalible_colors',avalible_colors)
            if len( avalible_colors ) != 0:
                for avalible_color in avalible_colors:
                    rand_avalible_color = avalible_color
                    break
                self.used_colors[rand_avalible_color].add(vertex_name)
                self.coloring[vertex_name] = rand_avalible_color
#             print('chosen_Color',self.coloring[vertex_name])

    def recolor_by_degree_reverse(self):
            """
            Использовать с candidates при ветвлении
            т.к в первоначальной окраске слишком много цветов
            скорее всего стоит красить не каждое ветвление, а мб только в начале
            """
        #     print('***recolor***')    
            self.sort_vertex_by_degree()
            max_color = -1
            self.coloring = dict()
            for vertex_name in self.V:
                self.coloring[vertex_name] = None
            self.used_colors = dict()
            for vertex_index in range(len(self.D)-1,-1,-1):
                vertex = self.D[vertex_index]
                vertex_name = vertex['name']
    #             print('vertex_name',vertex_name)
    #             print('used_Colors',self.used_colors)
                avalible_colors = set(self.used_colors.keys() )
                for neighbour_name in g.V[vertex_name]['neighbours']:
    #                 print('N',neighbour_name, self.coloring[neighbour_name] ,)
                    avalible_colors -= {self.coloring[neighbour_name]}
                    if len( avalible_colors ) == 0:
                        break
                if len( avalible_colors ) == 0:
                    max_color += 1 # color is index in candidates_coloring
                    self.used_colors[max_color] = set()
                    self.used_colors[max_color].add(vertex_name)
                    self.coloring[vertex_name] = max_color

    #             print('avalible_colors',avalible_colors)
                if len( avalible_colors ) != 0:
                    for avalible_color in avalible_colors:
                        rand_avalible_color = avalible_color
                        break
                    self.used_colors[rand_avalible_color].add(vertex_name)
                    self.coloring[vertex_name] = rand_avalible_color
    #             print('chosen_Color',self.coloring[vertex_name])
    #

# %%
def read_dimacs_graph(file_path):
    '''
        Parse .col file and return graph object
    '''
    g = Graph()
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith('c'):  # graph description
                print(*line.split()[1:])
            # first line: p name num_of_vertices num_of_edges
            elif line.startswith('p'):
                p, name, vertices_num, edges_num = line.split()
                print('{0} {1} {2}'.format(name, vertices_num, edges_num))
            elif line.startswith('e'):
                _, v1, v2 = line.split()
                g.add_edge(int(v1),int(v2))
            else:
                continue
        return g

# %%
path = 'C250.9.clq.txt'

# %%
path2 = 'C500.9.clq.txt'

# %%
path3 = 'brock800_4.clq.txt'

# %%
path4 = 'C125.9.clq.txt'

# %%
path_test = 'test.txt'

# %%
path_test_2 = 'test2.txt'

# %% [raw]
# file = open(path3, 'r')

# %%
g = read_dimacs_graph(path4);
# Out:
# FILE: C125.9.clq
#
# SOURCE: Generated by Michael Trick using
# ggen, a program by Craig Morgenstern
#
# DESCRIPTION: Cx.y is a random graph on x vertices
# with edge probability .y
#
#
# G(n,p) graph
# graph gen seed : 74328432
# number of vertices : 125
# max number of edges: 20000
# edge probability : 0.900000
# data structure : dense
#
# Graph Stats
# number of vertices : 125
# nonisolated vertices: 125
# number of edges : 6963
# edge density : 0.898452
# max degree : 119
# avg degree : 111.41
# min degree : 102
# edge 125 6963

# %%
# %%time
g.recolor()
c1 = len(g.used_colors)
g.clear_coloring()
# Out:
# Wall time: 6.98 ms

# %%
# %%time
g.recolor_by_degree()
c2 = len(g.used_colors)
g.clear_coloring()
# Out:
# Wall time: 8.98 ms

# %%
# %%time
g.recolor_by_degree_reverse()
c3 = len(g.used_colors)
g.clear_coloring()
# Out:
# Wall time: 7.98 ms

# %%
g.clear_coloring()

# %%
print('g.coloring()', c1)
print('g.coloring_by_degree()', c2)
print('g.coloring_by_degree_reverse()', c3)
# Out:
# g.coloring() 57
# g.coloring_by_degree() 56
# g.coloring_by_degree_reverse() 54

# %%
if c1 is min(c1,c2,c3):
    g.clear_coloring()
    g.recolor()
    
if c2 is min(c1,c2,c3):
    g.recolor_by_degree()
    g.recolor()
if c3 is min(c1,c2,c3):
    g.recolor_by_degree_reverse()
    g.recolor()

# %% [markdown]
# Клика - подграф, который является полным графом.
# То есть все вершины соединины друг с другом

# %%
def initial_heuristic_degree_2():
    clique = set()
    g.sort_vertex_by_degree()
#     print(type(clique))
    for vertex in g.D:
#         print(type(clique),type(vertex))
        
        all_elements_in_clique_are_neighbours_to_vertex = True
        for element in clique:
            all_elements_in_clique_are_neighbours_to_vertex = all_elements_in_clique_are_neighbours_to_vertex and g.is_neighbour(vertex['name'],element)
            if not all_elements_in_clique_are_neighbours_to_vertex:
                break
#         print(vertex['name'],all_elements_in_clique_are_neighbours_to_vertex )
        if all_elements_in_clique_are_neighbours_to_vertex:
            clique.add(vertex['name'])
    return clique

# %%
def initial_heuristic_color():
    """
    makes clique:
    first - vericies with maximal color
    """
    clique = set()
    g.sort_vertex_by_degree()
    
    for color in range(len(g.used_colors)):
        for vertex_name in g.used_colors[color]:
            all_elements_in_clique_are_neighbours_to_vertex = True
            for element_name in clique:
                all_elements_in_clique_are_neighbours_to_vertex = all_elements_in_clique_are_neighbours_to_vertex and g.is_neighbour(vertex_name,element_name)
                if not all_elements_in_clique_are_neighbours_to_vertex:
                    break
#             print(vertex_name,all_elements_in_clique_are_neighbours_to_vertex )
            if all_elements_in_clique_are_neighbours_to_vertex:
                clique.add(vertex_name)
    return clique

# %%
def initial_heuristic_color_reverse():
    """
    makes clique:
    first - vericies with maximal color
    """

    clique = set()
    g.sort_vertex_by_degree()
    
    for color in range(len(g.used_colors)-1,-1,-1):
        for vertex_name in g.used_colors[color]:
            all_elements_in_clique_are_neighbours_to_vertex = True
            for element_name in clique:
                all_elements_in_clique_are_neighbours_to_vertex = all_elements_in_clique_are_neighbours_to_vertex and g.is_neighbour(vertex_name,element_name)
                if not all_elements_in_clique_are_neighbours_to_vertex:
                    break
#             print(vertex_name,all_elements_in_clique_are_neighbours_to_vertex )
            if all_elements_in_clique_are_neighbours_to_vertex:
                clique.add(vertex_name)
    return clique

# %%
init_clique = initial_heuristic_color()

# %%
init_clique_rev = initial_heuristic_color_reverse()

# %%
init_clique_degree = initial_heuristic_degree_2()

# %%
len(init_clique)
# Out:
# 25

# %%
len(init_clique_rev)
# Out:
# 26

# %%
len(init_clique_degree)
# Out:
# 20

# %%
def candidates_used_colors(candidates:set):
    """
    работает только для первоначальной покраски командами для класса Graph()
    для проверки количества цветов уже перекрашенного множества candidates (с помощью candidates_recolor) использовать 
    len(candidates_coloring)
    """
    used_colors = set()
    for vertex_name in candidates:
        used_colors.add(g.V[vertex_name]['color'])
    return used_colors

# %%
def candidates_recolor_old(candidates:set):
    """
    Использовать с candidates при ветвлении
    т.к в первоначальной окраске слишком много цветов
    скорее всего стоит красить не каждое ветвление, а мб только в начале
    """
#     print('***candidates_recolor***')
    max_color = -1
    candidates_coloring = dict()
    for vertex_name in candidates:
        candidates_coloring[vertex_name] = None
    used_colors = dict()
    for vertex_name in candidates:
#         print('vertex_name',vertex_name)
#         print('used_Colors',used_colors)
        avalible_colors = set(used_colors.keys() )
        for neighbour_name in g.V[vertex_name]['neighbours'].intersection(candidates):
#             print('N',neighbour_name, candidates_coloring[neighbour_name] , neighbour_name in candidates)
            avalible_colors -= {candidates_coloring[neighbour_name]}
            if len( avalible_colors ) == 0:
                break
        if len( avalible_colors ) == 0:
            max_color += 1 # color is index in candidates_coloring
            used_colors[max_color] = set()
            used_colors[max_color].add(vertex_name)
            candidates_coloring[vertex_name] = max_color
        
#         print('avalible_colors',avalible_colors)
        if len( avalible_colors ) != 0:
            for avalible_color in avalible_colors:
                rand_avalible_color = avalible_color
                break
            used_colors[rand_avalible_color].add(vertex_name)
            candidates_coloring[vertex_name] = rand_avalible_color
#         print('chosen_Color',candidates_coloring[vertex_name])
    return used_colors,candidates_coloring

# %%
def candidates_recolor(candidates:set):
    """
    Использовать с candidates при ветвлении
    т.к в первоначальной окраске слишком много цветов
    скорее всего стоит красить не каждое ветвление, а мб только в начале
    """
#     print('***candidates_recolor***')
    max_color = 0
    candidates_coloring = dict()
    for vertex_name in candidates:
        candidates_coloring[vertex_name] = 0
    used_colors = {0: set()}
    for vertex_name in candidates:
#         print('vertex_name',vertex_name)
#         print('used_Colors',used_colors)
        neighbour_colors = set()
        for neighbour_name in g.V[vertex_name]['neighbours'].intersection(candidates):
#             print('N',neighbour_name, candidates_coloring[neighbour_name] , neighbour_name in candidates)
            neighbour_colors.add(candidates_coloring[neighbour_name])
            if len( neighbour_colors ) == len(used_colors):
#                 print('break')
                break
        if len( neighbour_colors ) == len(used_colors):
            max_color += 1 # color is index in candidates_coloring
            used_colors[max_color] = set()
            used_colors[max_color].add(vertex_name)
            candidates_coloring[vertex_name] = max_color
#             print(used_colors,candidates_coloring)
        
#         print('avalible_colors',avalible_colors)
        elif len( neighbour_colors ) < len(used_colors):
            avalible_colors = set(used_colors.keys()) - neighbour_colors
#             print('avalible_colors',avalible_colors)
            for avalible_color in avalible_colors:
                rand_avalible_color = avalible_color
                break
            used_colors[rand_avalible_color].add(vertex_name)
            candidates_coloring[vertex_name] = rand_avalible_color
#         print('chosen_Color',candidates_coloring[vertex_name])
    if len(candidates_coloring) != len(candidates):
        raise NameError('Not all verticies colored')
    return used_colors,candidates_coloring

# %%
def candidates_recolor_degree(candidates:set, rev = True):
    """
    Использовать с candidates при ветвлении
    т.к в первоначальной окраске слишком много цветов
    скорее всего стоит красить не каждое ветвление, а мб только в начале
    """
#     print('***candidates_recolor
    candidates_degree_order = list(candidates)
    candidates_degree_order.sort(key= lambda input: g.V[input]['degree'], reverse = rev)
    max_color = -1
    candidates_coloring = dict()
    for vertex_name in candidates:
        candidates_coloring[vertex_name] = None
    used_colors = dict()
    for vertex_name in candidates_degree_order:
#         print('vertex_name',vertex_name)
#         print('used_Colors',used_colors)
        avalible_colors = set(used_colors.keys() )
        for neighbour_name in g.V[vertex_name]['neighbours'].intersection(candidates):
#             print('N',neighbour_name, candidates_coloring[neighbour_name] , neighbour_name in candidates)
            avalible_colors -= {candidates_coloring[neighbour_name]}
            if len( avalible_colors ) == 0:
                break
        if len( avalible_colors ) == 0:
            max_color += 1 # color is index in candidates_coloring
            used_colors[max_color] = set()
            used_colors[max_color].add(vertex_name)
            candidates_coloring[vertex_name] = max_color
        
#         print('avalible_colors',avalible_colors)
        if len( avalible_colors ) != 0:
            for avalible_color in avalible_colors:
                rand_avalible_color = avalible_color
                break
            used_colors[rand_avalible_color].add(vertex_name)
            candidates_coloring[vertex_name] = rand_avalible_color
#         print('chosen_Color',candidates_coloring[vertex_name])
    return used_colors,candidates_coloring

# %%
clique = {'1','2'}

# %% [markdown]
# Првоерить могут ли быть в кандитдатах вершины из клики

# %%
def branching_order_old():
    """
    создает последовательность из вершин множества candidates такую, что в начало добавляются
    те вершины, при добавлении которых в клику новое множество кандидаы расскрашивается 
    в большое количество цветов.
    Если понятно, что ветвь не оптимальна, то она сразу не добавляется в очередь
    """
    
    global clique, candidates, len_max_current_clique
    
    order = []
    colors_on_branch = []
    for vertex in candidates:
#             print('color,vertex', color,vertex)
        
        clique.add(vertex)
        candidates_br = find_candidates()
        (colors_br,_) = candidates_recolor_degree(candidates_br)

        len_max_possible_clique_on_branch = len(colors_br) + len(clique)
#         print('len(clique)',len(clique))
#         print('max_branch_clique, max_cur_clique',len_max_possible_clique_on_branch, len_max_current_clique)
#         if len_max_possible_clique_on_branch > len_max_current_clique: #debug +100
        if len_max_possible_clique_on_branch  > len_max_current_clique: #debug +100

            order.append(vertex)
            colors_on_branch.append( len(colors_br) )
        else:
            print('baned vertex',vertex, 'with colors', len(colors_br)  )
        clique.remove(vertex)
            
    x = zip(order,colors_on_branch)
    xs = sorted(x, key=lambda tup: tup[1], reverse = True)

    order = [x[0] for x in xs]
    colors_on_branch = [x[1] for x in xs] 
#     print('clique, candidates, len_max_current_clique', clique, candidates, len_max_current_clique)
#     print('order',order)
#     print('colors_on_branch',colors_on_branch)

    return order,colors_on_branch

# %%
def branching_old():
    """
    прочитать граф
    расскрасить граф
    найти эвристику
    """
    global clique, candidates, len_max_current_clique, forbiden
    
    if len(candidates) == 0:
        len_max_current_clique = len(clique)
        
        print('Over of one branch. New max_clique = ', len_max_current_clique )
        print('clique is', clique)
        return
    
    order,colors_on_branch = branching_order()
#     print('len(clique) at start',len(clique))
#     print('len(colors) at start',len(colors), '\n')
#     if (len(clique) + len(colors) ) > len_max_current_clique:
#         print('OK')
#         print(len_max_current_clique)
#     else:
#         print("FIXME")
#     print('start on order', order)
#     print('forbiden on start', forbiden)
    forbiden_br = dict()
    print('new order', order)
    for vertex_index in range(len(order)):
        vertex = order[vertex_index]
        print('vertex_st',vertex, 'in order_st', order)

#         a1 = colors_on_branch[vertex_index] + len(clique) + 1
#         print('a1', vertex, a1,len_max_current_clique )
        if colors_on_branch[vertex_index] + len(clique) + 1 <= len_max_current_clique: #debug +100
#             print('skip branch for vertex:', vertex)
            continue
#         print('vertex', vertex)
        clique.add(vertex)
        candidates = find_candidates()
        if not set(forbiden.keys()).issubset(candidates):
            print('not set(forbiden.keys()).is_subset(candidates)')
            print(set(forbiden.keys()), candidates)
            clique.remove(vertex)
            if vertex in forbiden:
                forbiden[vertex] += 1
            else:
                forbiden[vertex] = 1

            if vertex in forbiden_br:
                forbiden_br[vertex] += 1
            else:
                forbiden_br[vertex] = 1
            print('vertex_end',vertex, 'in order_end', order)
            print('forbiden', forbiden)
            print('forbiden_br',forbiden_br)
#             сделать всякое разное
            continue
#         else:
#             print('set(forbiden.keys()).is_subset(candidates)')
#         print('len(candidates)', len(candidates) )
        (colors_br,_) = candidates_recolor_degree(candidates)
#         print('len(colors_br)',len(colors_br))
        len_max_possible_clique_on_branch = len(colors_br) + len(clique)
#         len_max_possible_clique_on_branch = 1000 # debug - del cell for work
#         print('len(clique)',len(clique))
#         print('max_branch_clique, max_cur_clique',len_max_possible_clique_on_branch, len_max_current_clique)
        a2 = len_max_possible_clique_on_branch
#         print('a2', vertex, a2,len_max_current_clique )
        if len_max_possible_clique_on_branch > len_max_current_clique:
#             print('branching with clique:')
#             print(clique)
#             print('new_Colors', len(colors_br) )
            branching_new()
#         else:
#             print('new_Colors', len(colors_br) )
#             print('branch skipped',a1,a2)
#         print('clique.remove', vertex , '\n')
        clique.remove(vertex)
        if vertex in forbiden:
            forbiden[vertex] += 1
        else:
            forbiden[vertex] = 1
        
        if vertex in forbiden_br:
            forbiden_br[vertex] += 1
        else:
            forbiden_br[vertex] = 1
        print('vertex_end',vertex, 'in order_end', order)
        print('forbiden', forbiden)
        print('forbiden_br',forbiden_br)
        
    for vertex in forbiden_br:
        forbiden[vertex] -= forbiden_br[vertex]
        if forbiden[vertex] == 0:
            forbiden.pop(vertex)
        if vertex in forbiden and forbiden[vertex] < 0:
            raise AssertionError('forbiden[vertex] < 0')
    forbiden_br = dict()

#     for vertex_index in range(len(order)):
#         vertex = order[vertex_index]
# #         print('remove from forbiden', vertex)
# #         print('forbiden', forbiden)
#         if vertex in forbiden:
#             forbiden.remove(vertex)

#     print('finish on order', order)

# %%
def find_candidates_old():
    """
    verticies - set of verticies names
    find all verticies, that are neigbours to all verticies in verticies
    if enter is empty - find all verticies of graph
    clique - глабавльная переменная
    """
    global clique
    candidates = set()
#     print('***find_candidates***')
#     print('clique',clique)
    if len(clique) == 0:
        candidates = set( g.V.keys() )
    for x in clique:
#         print(g.V[x]['name'])
        candidates = g.V[x]['neighbours'].copy()
        break
    for vertex in clique:
        candidates.intersection_update(g.V[vertex]['neighbours'])
#     print(candidates)
    return candidates

# %%
clique = {}

# %%
candidates = find_candidates()

# %%
clique = {1}
candidates = update_candidates(1)

# %%
clique.add(2)
candidates = update_candidates(2)

# %%
def find_candidates(vertex_to_clique = None):
    """
    если клика пустая создает множество из всех вершин графа
    если не пустая выдает ошибку - использовать update_candidates
    """
    global clique, candidates
    
    if len(clique) == 0:
        candidates = set( g.V.keys() )
    else:
        raise NameError('len(clique) =! 0. Use update_candidates')

    return candidates

# %%
len(candidates)
# Out:
# 63

# %%
cand_br = candidates.intersection(g.V[4]['neighbours'])

# %%
len(candidates)
# Out:
# 63

# %%
len(cand_br)
# Out:
# 55

# %%
(colors,_) = candidates_recolor(candidates)

# %%
len(candidates)
# Out:
# 102

# %%
(colors)
# Out:
# {0: {125},
#  1: {4, 22, 31},
#  2: {5, 23},
#  3: {6, 14},
#  4: {7, 78},
#  5: {8, 40},
#  6: {9, 32},
#  7: {10, 29},
#  8: {11, 26, 97},
#  9: {16, 21, 25},
#  10: {17, 30, 50},
#  11: {18, 27, 57},
#  12: {19, 60},
#  13: {24, 62},
#  14: {28, 38},
#  15: {33, 36},
#  16: {34, 58},
#  17: {35, 61, 79},
#  18: {39, 59, 122},
#  19: {41, 49},
#  20: {43, 65, 121},
#  21: {44, 119},
#  22: {45, 81},
#  23: {46, 47, 99},
#  24: {48, 51, 103},
#  25: {52, 71},
#  26: {54, 91},
#  27: {63, 74},
#  28: {64, 80},
#  29: {68, 73},
#  30: {69, 83},
#  31: {70, 84, 107},
#  32: {72, 76},
#  33: {77, 100},
#  34: {82, 89},
#  35: {85, 124},
#  36: {86, 88},
#  37: {92},
#  38: {93, 116},
#  39: {94, 96, 115},
#  40: {98, 123},
#  41: {101, 104},
#  42: {102, 110},
#  43: {105, 112},
#  44: {111},
#  45: {113, 117},
#  46: {114}}

# %%
b = [0,1,2,3,4,5,6,7,8]

# %%
b[len(b)-1]
# Out:
# 8

# %%
max_color  = 2

# %%
for i in range(len(b)-1,max_color-1,-1):
    print(b[i])
# Out:
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
colors,vertex_coloring = candidates_recolor(candidates)

# %%
vertex_coloring
# Out:
# {1: 1,
#  2: 2,
#  3: 2,
#  4: 3,
#  5: 4,
#  6: 5,
#  7: 6,
#  8: 7,
#  9: 8,
#  10: 9,
#  11: 10,
#  12: 8,
#  13: 11,
#  14: 11,
#  15: 10,
#  16: 12,
#  17: 13,
#  18: 14,
#  19: 15,
#  20: 9,
#  21: 12,
#  22: 3,
#  23: 4,
#  24: 16,
#  25: 12,
#  26: 17,
#  27: 17,
#  28: 18,
#  29: 19,
#  30: 13,
#  31: 18,
#  32: 20,
#  33: 21,
#  34: 20,
#  35: 22,
#  36: 21,
#  37: 1,
#  38: 23,
#  39: 24,
#  40: 7,
#  41: 25,
#  42: 26,
#  43: 27,
#  44: 28,
#  45: 29,
#  46: 26,
#  47: 30,
#  48: 31,
#  49: 25,
#  50: 13,
#  51: 10,
#  52: 14,
#  53: 19,
#  54: 32,
#  55: 31,
#  56: 24,
#  57: 28,
#  58: 6,
#  59: 33,
#  60: 15,
#  61: 22,
#  62: 16,
#  63: 34,
#  64: 35,
#  65: 33,
#  66: 36,
#  67: 37,
#  68: 38,
#  69: 39,
#  70: 27,
#  71: 11,
#  72: 40,
#  73: 38,
#  74: 34,
#  75: 40,
#  76: 40,
#  77: 41,
#  78: 5,
#  79: 22,
#  80: 35,
#  81: 29,
#  82: 30,
#  83: 26,
#  84: 24,
#  85: 39,
#  86: 42,
#  87: 37,
#  88: 8,
#  89: 43,
#  90: 41,
#  91: 32,
#  92: 36,
#  93: 44,
#  94: 45,
#  95: 1,
#  96: 43,
#  97: 16,
#  98: 23,
#  99: 30,
#  100: 46,
#  101: 47,
#  102: 14,
#  103: 48,
#  104: 47,
#  105: 48,
#  106: 45,
#  107: 49,
#  108: 6,
#  109: 44,
#  110: 50,
#  111: 51,
#  112: 29,
#  113: 52,
#  114: 53,
#  115: 54,
#  116: 55,
#  117: 42,
#  118: 49,
#  119: 54,
#  120: 56,
#  121: 57,
#  122: 58,
#  123: 52,
#  124: 37,
#  125: 0}

# %%
len(candidates)
# Out:
# 102

# %%
def update_candidates(used_candidates = None, candidates = None, vertex_to_clique = None):
    """
    если клика пустая выдает ошибку - нужно использовать find_candidates
    если клика не пустая то обновляет множетсво кандидитов:
        в него включаются те вершины, которые есть в кандидатах
        и те вершины, которые есть в соседях у вершины vertex_to_clique, которая
        в данный момент добавляется в клику
    """
    global clique #, candidates
    
    if len(clique) == 0:
        raise NameError('len(clique) == 0. Use find_candidates')
    if candidates is None:
        raise NameError('candidates = None')
    if used_candidates is None:
        used_candidates = set()
    else:
        if vertex_to_clique not in candidates:
            raise NameError(vertex_to_clique,'No such vertex in candidates')
        updated_candidates = candidates.intersection(g.V[vertex_to_clique]['neighbours']) - used_candidates
    return updated_candidates

# %%
def branching_order(candidates,colors):
    """
    создает последовательность из вершин множества candidates такую, что в начало добавляются
    те вершины, при добавлении которых в клику новое множество кандидаы расскрашивается 
    в большое количество цветов.
    Если понятно, что ветвь не оптимальна, то она сразу не добавляется в очередь
    """
    
    global clique, len_max_current_clique #, colors # candidates,
    colors_num = len(colors) # colors надо полуить до использования функции
    candidates_order = []
    # len(cloque) + color of vertex > len_max_current_clique
    # дальше используем вершины с цветом, удовлетворяющим этому условию
    # colors = 0,1,2,3,4...
    last_color = len_max_current_clique - len(clique) # вроде без +1
    for color in range(colors_num - 1, max(last_color - 1,-1), -1):
        for vertex in colors[color]:
            if not vertex in clique:
                candidates_order.append(vertex)
    
    
    
    return candidates_order

# %%
def branching_new(candidates, used_candidates):
    """
    прочитать граф
    расскрасить граф
    найти эвристику
    """
    global clique, len_max_current_clique #, candidates
    
    if len(candidates) == 0:
        len_max_current_clique = len(clique)
        print('Over of one branch. New max_clique = ', len_max_current_clique )
        print('clique is', clique)
        return
    
    (colors,vertex_coloring) = candidates_recolor(candidates)
    colors_num_of_candidates = len(colors)
    if colors_num_of_candidates + len(clique) < len_max_current_clique:
        print('skipped', candidates)
        return
    candidates_order = branching_order(candidates,colors)

    print('start candidates_order',candidates_order)
    print('start used_candidates', used_candidates)
    for vertex in candidates_order:
        print('start vertex',vertex, 'on order',candidates_order, 'with used_candidates',used_candidates  )
        vertex_color = vertex_coloring[vertex]
        if (vertex_color + 1) + len(clique) <= len_max_current_clique: # len_max_current_clique может измениться. Поэтому проверяем
            for vertex_1 in candidates_order:
                if vertex_1 == vertex:
                    break
                used_candidates.remove(vertex_1)
            print('break',vertex,'on order', candidates_order)
            break # все вершиниы дальше по списку тоже не удовлетворяют этому условию
            # добвить оставшиеся в used_candidates
        clique.add(vertex)
        print('clique',len(clique),clique)
        candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#         print('candidates_br',candidates_br)
        branching_new(candidates_br, used_candidates)
        used_candidates.add(vertex)
        clique.remove(vertex)
        print('finish vertex',vertex)
    else:
        for vertex in candidates_order:
            print(candidates_order)
            used_candidates.remove(vertex)

    print('finish candidates_order',candidates_order)

# %%
clique = set()
candidates = find_candidates()
used_candidates = set()
len_max_current_clique = 1
branching_new(candidates,used_candidates)
# Out:
# start candidates_order [122, 121, 120, 116, 115, 119, 114, 113, 123, 111, 110, 107, 118, 105, 103, 104, 101, 100, 106, 94, 109, 93, 96, 89, 117, 86, 90, 77, 72, 75, 76, 85, 69, 73, 68, 67, 124, 87, 66, 92, 64, 80, 74, 63, 65, 59, 91, 54, 48, 55, 82, 99, 47, 112, 81, 45, 57, 44, 43, 70, 42, 83, 46, 41, 49, 56, 84, 39, 98, 38, 35, 61, 79, 33, 36, 32, 34, 53, 29, 28, 31, 26, 27, 24, 97, 62, 19, 60, 18, 52, 102, 17, 50, 30, 16, 25, 21, 13, 14, 71, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 58, 108, 7, 78, 6, 5, 23, 4, 22, 2, 3, 1, 37, 95]
# start used_candidates set()
# start vertex 122 on order [122, 121, 120, 116, 115, 119, 114, 113, 123, 111, 110, 107, 118, 105, 103, 104, 101, 100, 106, 94, 109, 93, 96, 89, 117, 86, 90, 77, 72, 75, 76, 85, 69, 73, 68, 67, 124, 87, 66, 92, 64, 80, 74, 63, 65, 59, 91, 54, 48, 55, 82, 99, 47, 112, 81, 45, 57, 44, 43, 70, 42, 83, 46, 41, 49, 56, 84, 39, 98, 38, 35, 61, 79, 33, 36, 32, 34, 53, 29, 28, 31, 26, 27, 24, 97, 62, 19, 60, 18, 52, 102, 17, 50, 30, 16, 25, 21, 13, 14, 71, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 58, 108, 7, 78, 6, 5, 23, 4, 22, 2, 3, 1, 37, 95] with used_candidates set()
# clique 1 {122}
# start candidates_order [123, 119, 117, 118, 114, 111, 110, 108, 109, 103, 104, 101, 100, 99, 102, 96, 115, 94, 116, 93, 120, 92, 89, 82, 85, 69, 68, 78, 67, 124, 87, 66, 74, 64, 80, 63, 55, 91, 54, 48, 52, 83, 61, 47, 112, 81, 45, 57, 44, 65, 43, 121, 41, 49, 98, 38, 35, 79, 33, 107, 77, 32, 34, 75, 29, 46, 28, 76, 31, 26, 27, 24, 97, 62, 19, 60, 113, 18, 17, 50, 30, 16, 25, 21, 13, 14, 71, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 86, 7, 70, 6, 5, 23, 4, 22, 56, 2, 3, 1, 37, 125]
# start used_candidates set()
# start vertex 123 on order [123, 119, 117, 118, 114, 111, 110, 108, 109, 103, 104, 101, 100, 99, 102, 96, 115, 94, 116, 93, 120, 92, 89, 82, 85, 69, 68, 78, 67, 124, 87, 66, 74, 64, 80, 63, 55, 91, 54, 48, 52, 83, 61, 47, 112, 81, 45, 57, 44, 65, 43, 121, 41, 49, 98, 38, 35, 79, 33, 107, 77, 32, 34, 75, 29, 46, 28, 76, 31, 26, 27, 24, 97, 62, 19, 60, 113, 18, 17, 50, 30, 16, 25, 21, 13, 14, 71, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 86, 7, 70, 6, 5, 23, 4, 22, 56, 2, 3, 1, 37, 125] with used_candidates set()
# clique 2 {122, 123}
# start candidates_order [117, 118, 115, 119, 114, 111, 110, 104, 101, 96, 100, 93, 120, 92, 109, 85, 89, 82, 83, 69, 103, 68, 78, 67, 124, 87, 64, 80, 74, 63, 55, 54, 48, 52, 61, 47, 112, 81, 45, 57, 44, 65, 43, 121, 41, 49, 99, 38, 35, 79, 33, 107, 77, 32, 34, 75, 29, 46, 28, 76, 31, 26, 27, 24, 97, 62, 19, 60, 18, 17, 50, 30, 16, 25, 21, 13, 14, 71, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 108, 7, 70, 6, 5, 23, 4, 22, 56, 2, 3, 1, 37, 125]
# start used_candidates set()
# start vertex 117 on order [117, 118, 115, 119, 114, 111, 110, 104, 101, 96, 100, 93, 120, 92, 109, 85, 89, 82, 83, 69, 103, 68, 78, 67, 124, 87, 64, 80, 74, 63, 55, 54, 48, 52, 61, 47, 112, 81, 45, 57, 44, 65, 43, 121, 41, 49, 99, 38, 35, 79, 33, 107, 77, 32, 34, 75, 29, 46, 28, 76, 31, 26, 27, 24, 97, 62, 19, 60, 18, 17, 50, 30, 16, 25, 21, 13, 14, 71, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 108, 7, 70, 6, 5, 23, 4, 22, 56, 2, 3, 1, 37, 125] with used_candidates set()
# clique 3 {122, 123, 117}
# start candidates_order [114, 110, 104, 103, 96, 101, 109, 93, 124, 85, 89, 82, 80, 92, 120, 77, 75, 108, 79, 107, 70, 83, 100, 69, 68, 78, 67, 87, 74, 63, 55, 54, 48, 52, 61, 47, 112, 81, 45, 56, 44, 65, 43, 121, 41, 49, 99, 38, 115, 35, 64, 34, 33, 71, 29, 46, 28, 31, 26, 27, 24, 111, 19, 60, 57, 18, 17, 50, 30, 16, 25, 21, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 7, 6, 14, 5, 23, 4, 22, 2, 13, 1, 37, 125]
# start used_candidates set()
# start vertex 114 on order [114, 110, 104, 103, 96, 101, 109, 93, 124, 85, 89, 82, 80, 92, 120, 77, 75, 108, 79, 107, 70, 83, 100, 69, 68, 78, 67, 87, 74, 63, 55, 54, 48, 52, 61, 47, 112, 81, 45, 56, 44, 65, 43, 121, 41, 49, 99, 38, 115, 35, 64, 34, 33, 71, 29, 46, 28, 31, 26, 27, 24, 111, 19, 60, 57, 18, 17, 50, 30, 16, 25, 21, 51, 11, 15, 10, 20, 88, 9, 12, 8, 40, 7, 6, 14, 5, 23, 4, 22, 2, 13, 1, 37, 125] with used_candidates set()
# clique 4 {122, 123, 117, 114}
# start candidates_order [115, 111, 110, 104, 96, 101, 88, 120, 112, 89, 85, 80, 92, 100, 77, 107, 70, 83, 69, 68, 78, 67, 87, 74, 63, 56, 55, 54, 52, 61, 48, 51, 103, 82, 99, 47, 93, 45, 44, 109, 65, 43, 121, 41, 49, 35, 79, 34, 75, 33, 71, 29, 46, 28, 38, 19, 60, 57, 18, 27, 17, 50, 30, 16, 25, 21, 11, 124, 15, 10, 20, 9, 26, 8, 40, 108, 14, 7, 5, 23, 4, 22, 31, 2, 13, 1, 37, 125]
# start used_candidates set()
# start vertex 115 on order [115, 111, 110, 104, 96, 101, 88, 120, 112, 89, 85, 80, 92, 100, 77, 107, 70, 83, 69, 68, 78, 67, 87, 74, 63, 56, 55, 54, 52, 61, 48, 51, 103, 82, 99, 47, 93, 45, 44, 109, 65, 43, 121, 41, 49, 35, 79, 34, 75, 33, 71, 29, 46, 28, 38, 19, 60, 57, 18, 27, 17, 50, 30, 16, 25, 21, 11, 124, 15, 10, 20, 9, 26, 8, 40, 108, 14, 7, 5, 23, 4, 22, 31, 2, 13, 1, 37, 125] with used_candidates set()
# clique 5 {114, 115, 117, 122, 123}
# start candidates_order [124, 111, 110, 104, 101, 99, 88, 87, 109, 85, 89, 82, 80, 92, 79, 120, 77, 74, 103, 71, 107, 70, 83, 100, 69, 68, 78, 56, 55, 54, 48, 52, 61, 47, 93, 45, 57, 44, 65, 43, 121, 41, 49, 34, 75, 29, 46, 112, 28, 38, 19, 60, 18, 27, 17, 50, 30, 16, 25, 21, 51, 11, 15, 10, 20, 9, 26, 8, 40, 14, 7, 5, 23, 4, 22, 31, 2, 13, 1, 37, 125]
# start used_candidates set()
# start vertex 124 on order [124, 111, 110, 104, 101, 99, 88, 87, 109, 85, 89, 82, 80, 92, 79, 120, 77, 74, 103, 71, 107, 70, 83, 100, 69, 68, 78, 56, 55, 54, 48, 52, 61, 47, 93, 45, 57, 44, 65, 43, 121, 41, 49, 34, 75, 29, 46, 112, 28, 38, 19, 60, 18, 27, 17, 50, 30, 16, 25, 21, 51, 11, 15, 10, 20, 9, 26, 8, 40, 14, 7, 5, 23, 4, 22, 31, 2, 13, 1, 37, 125] with used_candidates set()
# clique 6 {114, 115, 117, 122, 123, 124}
# start candidates_order [111, 110, 104, 101, 99, 109, 88, 89, 82, 80, 92, 120, 77, 74, 75, 71, 112, 70, 68, 78, 61, 79, 60, 56, 55, 54, 49, 100, 69, 48, 51, 103, 83, 46, 47, 93, 45, 65, 43, 121, 34, 28, 38, 26, 52, 57, 18, 27, 17, 50, 30, 16, 25, 21, 10, 29, 8, 40, 14, 7, 5, 23, 4, 22, 31, 2, 20, 1, 37, 125]
# start used_candidates set()
# start vertex 111 on order [111, 110, 104, 101, 99, 109, 88, 89, 82, 80, 92, 120, 77, 74, 75, 71, 112, 70, 68, 78, 61, 79, 60, 56, 55, 54, 49, 100, 69, 48, 51, 103, 83, 46, 47, 93, 45, 65, 43, 121, 34, 28, 38, 26, 52, 57, 18, 27, 17, 50, 30, 16, 25, 21, 10, 29, 8, 40, 14, 7, 5, 23, 4, 22, 31, 2, 20, 1, 37, 125] with used_candidates set()
# clique 7 {111, 114, 115, 117, 122, 123, 124}
# start candidates_order [121, 110, 104, 101, 99, 109, 93, 89, 82, 80, 92, 120, 77, 74, 88, 71, 68, 78, 61, 79, 60, 56, 55, 54, 49, 100, 69, 48, 51, 103, 83, 46, 47, 43, 70, 34, 75, 50, 30, 112, 28, 38, 26, 52, 57, 18, 27, 16, 25, 21, 10, 29, 8, 40, 14, 7, 5, 23, 4, 22, 2, 20, 1, 37, 125]
# start used_candidates set()
# start vertex 121 on order [121, 110, 104, 101, 99, 109, 93, 89, 82, 80, 92, 120, 77, 74, 88, 71, 68, 78, 61, 79, 60, 56, 55, 54, 49, 100, 69, 48, 51, 103, 83, 46, 47, 43, 70, 34, 75, 50, 30, 112, 28, 38, 26, 52, 57, 18, 27, 16, 25, 21, 10, 29, 8, 40, 14, 7, 5, 23, 4, 22, 2, 20, 1, 37, 125] with used_candidates set()
# clique 8 {111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [110, 104, 101, 109, 93, 83, 103, 80, 92, 100, 77, 71, 70, 120, 68, 60, 56, 55, 54, 52, 61, 50, 79, 49, 57, 48, 51, 82, 99, 47, 40, 74, 34, 75, 29, 112, 28, 38, 26, 27, 18, 30, 16, 21, 14, 7, 5, 23, 25, 4, 2, 20, 1, 37, 125]
# start used_candidates set()
# start vertex 110 on order [110, 104, 101, 109, 93, 83, 103, 80, 92, 100, 77, 71, 70, 120, 68, 60, 56, 55, 54, 52, 61, 50, 79, 49, 57, 48, 51, 82, 99, 47, 40, 74, 34, 75, 29, 112, 28, 38, 26, 27, 18, 30, 16, 21, 14, 7, 5, 23, 25, 4, 2, 20, 1, 37, 125] with used_candidates set()
# clique 9 {110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [104, 101, 109, 93, 83, 100, 80, 92, 77, 71, 70, 120, 68, 60, 74, 55, 54, 52, 61, 50, 79, 49, 57, 48, 51, 103, 82, 99, 47, 40, 34, 75, 112, 28, 38, 26, 27, 18, 30, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 56, 1, 125]
# start used_candidates set()
# start vertex 104 on order [104, 101, 109, 93, 83, 100, 80, 92, 77, 71, 70, 120, 68, 60, 74, 55, 54, 52, 61, 50, 79, 49, 57, 48, 51, 103, 82, 99, 47, 40, 34, 75, 112, 28, 38, 26, 27, 18, 30, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 56, 1, 125] with used_candidates set()
# clique 10 {104, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [109, 93, 82, 99, 80, 79, 100, 77, 70, 120, 68, 60, 92, 74, 55, 54, 52, 71, 51, 103, 49, 57, 83, 61, 47, 40, 112, 34, 75, 50, 30, 48, 28, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 56, 1, 125]
# start used_candidates set()
# start vertex 109 on order [109, 93, 82, 99, 80, 79, 100, 77, 70, 120, 68, 60, 92, 74, 55, 54, 52, 71, 51, 103, 49, 57, 83, 61, 47, 40, 112, 34, 75, 50, 30, 48, 28, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 56, 1, 125] with used_candidates set()
# clique 11 {104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [82, 80, 100, 77, 70, 120, 68, 60, 92, 57, 74, 56, 55, 54, 52, 71, 51, 83, 61, 47, 40, 112, 34, 75, 50, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125]
# start used_candidates set()
# start vertex 82 on order [82, 80, 100, 77, 70, 120, 68, 60, 92, 57, 74, 56, 55, 54, 52, 71, 51, 83, 61, 47, 40, 112, 34, 75, 50, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates set()
# clique 12 {104, 109, 110, 111, 114, 115, 82, 117, 121, 122, 123, 124}
# start candidates_order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125]
# start used_candidates set()
# start vertex 83 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates set()
# clique 13 {104, 109, 110, 111, 114, 115, 82, 117, 83, 121, 122, 123, 124}
# start candidates_order [56, 54, 52, 51, 40, 112, 34, 29, 57, 27, 25, 80, 92, 28, 79, 120, 77, 30, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 2, 75, 60]
# start used_candidates set()
# start vertex 56 on order [56, 54, 52, 51, 40, 112, 34, 29, 57, 27, 25, 80, 92, 28, 79, 120, 77, 30, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 2, 75, 60] with used_candidates set()
# clique 14 {104, 109, 110, 111, 114, 115, 82, 117, 83, 56, 121, 122, 123, 124}
# start candidates_order [52, 51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 92, 79, 120, 77, 75, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60]
# start used_candidates set()
# start vertex 52 on order [52, 51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 92, 79, 120, 77, 75, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60] with used_candidates set()
# clique 15 {104, 109, 110, 111, 114, 115, 82, 117, 83, 52, 56, 121, 122, 123, 124}
# start candidates_order [51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 120, 77, 75, 79, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60]
# start used_candidates set()
# start vertex 51 on order [51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 120, 77, 75, 79, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60] with used_candidates set()
# clique 16 {51, 104, 109, 110, 111, 114, 115, 82, 117, 83, 52, 56, 121, 122, 123, 124}
# start candidates_order [40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 77, 75, 79, 14, 7, 70, 23, 20, 5, 16, 68, 60]
# start used_candidates set()
# start vertex 40 on order [40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 77, 75, 79, 14, 7, 70, 23, 20, 5, 16, 68, 60] with used_candidates set()
# clique 17 {51, 104, 40, 109, 110, 111, 114, 115, 82, 117, 83, 52, 56, 121, 122, 123, 124}
# start candidates_order [54, 34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 30, 60]
# start used_candidates set()
# start vertex 54 on order [54, 34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 30, 60] with used_candidates set()
# clique 18 {51, 104, 40, 109, 110, 111, 114, 115, 82, 117, 83, 52, 56, 121, 122, 123, 124, 54}
# start candidates_order [34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60]
# start used_candidates set()
# start vertex 34 on order [34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60] with used_candidates set()
# clique 19 {34, 40, 51, 52, 54, 56, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60]
# start used_candidates set()
# start vertex 29 on order [29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60] with used_candidates set()
# clique 20 {29, 34, 40, 51, 52, 54, 56, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [27, 25, 28, 60, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 57]
# start used_candidates set()
# start vertex 27 on order [27, 25, 28, 60, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 57] with used_candidates set()
# clique 21 {27, 29, 34, 40, 51, 52, 54, 56, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [25, 23, 80, 28, 79, 77, 14, 7, 20, 70, 68, 60]
# start used_candidates set()
# start vertex 25 on order [25, 23, 80, 28, 79, 77, 14, 7, 20, 70, 68, 60] with used_candidates set()
# clique 22 {25, 27, 29, 34, 40, 51, 52, 54, 56, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [80, 79, 77, 14, 7, 20, 70, 68, 60]
# start used_candidates set()
# start vertex 80 on order [80, 79, 77, 14, 7, 20, 70, 68, 60] with used_candidates set()
# clique 23 {25, 27, 29, 34, 40, 51, 52, 54, 56, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [79, 77, 14, 7, 20, 70, 68, 60]
# start used_candidates set()
# start vertex 79 on order [79, 77, 14, 7, 20, 70, 68, 60] with used_candidates set()
# clique 24 {25, 27, 29, 34, 40, 51, 52, 54, 56, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [77, 60, 7, 20, 70, 68, 14]
# start used_candidates set()
# start vertex 77 on order [77, 60, 7, 20, 70, 68, 14] with used_candidates set()
# clique 25 {25, 27, 29, 34, 40, 51, 52, 54, 56, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60, 7, 20, 70, 68, 14]
# start used_candidates set()
# start vertex 60 on order [60, 7, 20, 70, 68, 14] with used_candidates set()
# clique 26 {25, 27, 29, 34, 40, 51, 52, 54, 56, 60, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [20, 70, 68, 14, 7]
# start used_candidates set()
# start vertex 20 on order [20, 70, 68, 14, 7] with used_candidates set()
# clique 27 {20, 25, 27, 29, 34, 40, 51, 52, 54, 56, 60, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [68, 14, 7]
# start used_candidates set()
# start vertex 68 on order [68, 14, 7] with used_candidates set()
# clique 28 {20, 25, 27, 29, 34, 40, 51, 52, 54, 56, 60, 68, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [14, 7]
# start used_candidates set()
# start vertex 14 on order [14, 7] with used_candidates set()
# clique 29 {14, 20, 25, 27, 29, 34, 40, 51, 52, 54, 56, 60, 68, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# Over of one branch. New max_clique =  29
# clique is {14, 20, 25, 27, 29, 34, 40, 51, 52, 54, 56, 60, 68, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# finish vertex 14
# start vertex 7 on order [14, 7] with used_candidates {14}
# break 7 on order [14, 7]
# finish candidates_order [14, 7]
# finish vertex 68
# start vertex 14 on order [68, 14, 7] with used_candidates {68}
# break 14 on order [68, 14, 7]
# finish candidates_order [68, 14, 7]
# finish vertex 20
# start vertex 70 on order [20, 70, 68, 14, 7] with used_candidates {20}
# break 70 on order [20, 70, 68, 14, 7]
# finish candidates_order [20, 70, 68, 14, 7]
# finish vertex 60
# start vertex 7 on order [60, 7, 20, 70, 68, 14] with used_candidates {60}
# break 7 on order [60, 7, 20, 70, 68, 14]
# finish candidates_order [60, 7, 20, 70, 68, 14]
# finish vertex 77
# start vertex 60 on order [77, 60, 7, 20, 70, 68, 14] with used_candidates {77}
# break 60 on order [77, 60, 7, 20, 70, 68, 14]
# finish candidates_order [77, 60, 7, 20, 70, 68, 14]
# finish vertex 79
# start vertex 77 on order [79, 77, 14, 7, 20, 70, 68, 60] with used_candidates {79}
# break 77 on order [79, 77, 14, 7, 20, 70, 68, 60]
# finish candidates_order [79, 77, 14, 7, 20, 70, 68, 60]
# finish vertex 80
# start vertex 79 on order [80, 79, 77, 14, 7, 20, 70, 68, 60] with used_candidates {80}
# break 79 on order [80, 79, 77, 14, 7, 20, 70, 68, 60]
# finish candidates_order [80, 79, 77, 14, 7, 20, 70, 68, 60]
# finish vertex 25
# start vertex 23 on order [25, 23, 80, 28, 79, 77, 14, 7, 20, 70, 68, 60] with used_candidates {25}
# break 23 on order [25, 23, 80, 28, 79, 77, 14, 7, 20, 70, 68, 60]
# finish candidates_order [25, 23, 80, 28, 79, 77, 14, 7, 20, 70, 68, 60]
# finish vertex 27
# start vertex 25 on order [27, 25, 28, 60, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 57] with used_candidates {27}
# clique 21 {25, 29, 34, 40, 51, 52, 54, 56, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57]
# start used_candidates {27}
# start vertex 57 on order [57] with used_candidates {27}
# clique 22 {25, 29, 34, 40, 51, 52, 54, 56, 57, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [80]
# start used_candidates {27}
# start vertex 80 on order [80] with used_candidates {27}
# clique 23 {25, 29, 34, 40, 51, 52, 54, 56, 57, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [79]
# start used_candidates {27}
# start vertex 79 on order [79] with used_candidates {27}
# clique 24 {25, 29, 34, 40, 51, 52, 54, 56, 57, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [77]
# start used_candidates {27}
# start vertex 77 on order [77] with used_candidates {27}
# clique 25 {25, 29, 34, 40, 51, 52, 54, 56, 57, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [14, 7]
# start used_candidates {27}
# start vertex 14 on order [14, 7] with used_candidates {27}
# clique 26 {14, 25, 29, 34, 40, 51, 52, 54, 56, 57, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [70]
# start used_candidates {27}
# start vertex 70 on order [70] with used_candidates {27}
# clique 27 {14, 25, 29, 34, 40, 51, 52, 54, 56, 57, 70, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [5]
# start used_candidates {27}
# start vertex 5 on order [5] with used_candidates {27}
# clique 28 {5, 14, 25, 29, 34, 40, 51, 52, 54, 56, 57, 70, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [68]
# start used_candidates {27}
# start vertex 68 on order [68] with used_candidates {27}
# clique 29 {5, 14, 25, 29, 34, 40, 51, 52, 54, 56, 57, 68, 70, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {27}
# start vertex 60 on order [60] with used_candidates {27}
# clique 30 {5, 14, 25, 29, 34, 40, 51, 52, 54, 56, 57, 60, 68, 70, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# Over of one branch. New max_clique =  30
# clique is {5, 14, 25, 29, 34, 40, 51, 52, 54, 56, 57, 60, 68, 70, 77, 79, 80, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# finish vertex 60
# [60]
# finish candidates_order [60]
# finish vertex 68
# [68]
# finish candidates_order [68]
# finish vertex 5
# [5]
# finish candidates_order [5]
# finish vertex 70
# [70]
# finish candidates_order [70]
# finish vertex 14
# start vertex 7 on order [14, 7] with used_candidates {27, 14}
# break 7 on order [14, 7]
# finish candidates_order [14, 7]
# finish vertex 77
# [77]
# finish candidates_order [77]
# finish vertex 79
# [79]
# finish candidates_order [79]
# finish vertex 80
# [80]
# finish candidates_order [80]
# finish vertex 57
# [57]
# finish candidates_order [57]
# finish vertex 25
# start vertex 28 on order [27, 25, 28, 60, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 57] with used_candidates {27, 25}
# break 28 on order [27, 25, 28, 60, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 57]
# finish candidates_order [27, 25, 28, 60, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 57]
# finish vertex 29
# start vertex 57 on order [29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60] with used_candidates {29}
# break 57 on order [29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60]
# finish candidates_order [29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60]
# finish vertex 34
# start vertex 29 on order [34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60] with used_candidates {34}
# break 29 on order [34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60]
# finish candidates_order [34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 60]
# finish vertex 54
# start vertex 34 on order [54, 34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 30, 60] with used_candidates {54}
# break 34 on order [54, 34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 30, 60]
# finish candidates_order [54, 34, 29, 57, 27, 25, 28, 80, 79, 77, 14, 7, 70, 23, 20, 5, 68, 30, 60]
# finish vertex 40
# start vertex 112 on order [40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 77, 75, 79, 14, 7, 70, 23, 20, 5, 16, 68, 60] with used_candidates {40}
# break 112 on order [40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 77, 75, 79, 14, 7, 70, 23, 20, 5, 16, 68, 60]
# finish candidates_order [40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 77, 75, 79, 14, 7, 70, 23, 20, 5, 16, 68, 60]
# finish vertex 51
# start vertex 40 on order [51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 120, 77, 75, 79, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60] with used_candidates {51}
# break 40 on order [51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 120, 77, 75, 79, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60]
# finish candidates_order [51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 120, 77, 75, 79, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60]
# finish vertex 52
# start vertex 51 on order [52, 51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 92, 79, 120, 77, 75, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60] with used_candidates {52}
# break 51 on order [52, 51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 92, 79, 120, 77, 75, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60]
# finish candidates_order [52, 51, 40, 112, 34, 54, 30, 29, 57, 27, 25, 28, 80, 92, 79, 120, 77, 75, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 60]
# finish vertex 56
# start vertex 54 on order [56, 54, 52, 51, 40, 112, 34, 29, 57, 27, 25, 80, 92, 28, 79, 120, 77, 30, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 2, 75, 60] with used_candidates {56}
# clique 14 {54, 82, 83, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {56}
# finish candidates_order []
# finish vertex 54
# start vertex 52 on order [56, 54, 52, 51, 40, 112, 34, 29, 57, 27, 25, 80, 92, 28, 79, 120, 77, 30, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 2, 75, 60] with used_candidates {56, 54}
# break 52 on order [56, 54, 52, 51, 40, 112, 34, 29, 57, 27, 25, 80, 92, 28, 79, 120, 77, 30, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 2, 75, 60]
# finish candidates_order [56, 54, 52, 51, 40, 112, 34, 29, 57, 27, 25, 80, 92, 28, 79, 120, 77, 30, 71, 14, 7, 70, 23, 74, 20, 5, 16, 68, 2, 75, 60]
# finish vertex 83
# start vertex 80 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates {83}
# clique 13 {80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [100, 77, 112, 70]
# start used_candidates {83}
# start vertex 100 on order [100, 77, 112, 70] with used_candidates {83}
# clique 14 {80, 82, 100, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {83}
# finish candidates_order []
# finish vertex 100
# start vertex 77 on order [100, 77, 112, 70] with used_candidates {100, 83}
# clique 14 {77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {100, 83}
# start vertex 60 on order [60] with used_candidates {100, 83}
# clique 15 {60, 77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55]
# start used_candidates {100, 83}
# start vertex 56 on order [56, 55] with used_candidates {100, 83}
# clique 16 {56, 60, 77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [54]
# start used_candidates {100, 83}
# start vertex 54 on order [54] with used_candidates {100, 83}
# clique 17 {54, 56, 60, 77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [52]
# start used_candidates {100, 83}
# start vertex 52 on order [52] with used_candidates {100, 83}
# clique 18 {52, 54, 56, 60, 77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {100, 83}
# finish candidates_order []
# finish vertex 52
# [52]
# finish candidates_order [52]
# finish vertex 54
# [54]
# finish candidates_order [54]
# finish vertex 56
# start vertex 55 on order [56, 55] with used_candidates {83, 100, 56}
# clique 16 {55, 60, 77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [54]
# start used_candidates {83, 100, 56}
# start vertex 54 on order [54] with used_candidates {83, 100, 56}
# clique 17 {55, 54, 60, 77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [52]
# start used_candidates {83, 100, 56}
# start vertex 52 on order [52] with used_candidates {83, 100, 56}
# clique 18 {52, 55, 54, 60, 77, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {83, 100, 56}
# finish candidates_order []
# finish vertex 52
# [52]
# finish candidates_order [52]
# finish vertex 54
# [54]
# finish candidates_order [54]
# finish vertex 55
# [56, 55]
# [56, 55]
# finish candidates_order [56, 55]
# finish vertex 60
# [60]
# finish candidates_order [60]
# finish vertex 77
# start vertex 112 on order [100, 77, 112, 70] with used_candidates {83, 100, 77}
# clique 14 {80, 82, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {83, 100, 77}
# finish candidates_order []
# finish vertex 112
# start vertex 70 on order [100, 77, 112, 70] with used_candidates {100, 77, 112, 83}
# clique 14 {70, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {100, 77, 112, 83}
# start vertex 60 on order [60] with used_candidates {100, 77, 112, 83}
# clique 15 {60, 70, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57]
# start used_candidates {100, 77, 112, 83}
# start vertex 57 on order [57] with used_candidates {100, 77, 112, 83}
# clique 16 {57, 60, 70, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55]
# start used_candidates {100, 77, 112, 83}
# start vertex 56 on order [56, 55] with used_candidates {100, 77, 112, 83}
# clique 17 {56, 57, 60, 70, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# skipped {4, 5, 7, 14, 25, 28, 29, 30, 34, 40, 51, 52, 54, 68, 71, 75, 79, 120, 125}
# finish vertex 56
# start vertex 55 on order [56, 55] with used_candidates {100, 77, 112, 83, 56}
# clique 17 {55, 57, 60, 70, 80, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {100, 77, 112, 83, 56}
# finish candidates_order []
# finish vertex 55
# [56, 55]
# [56, 55]
# finish candidates_order [56, 55]
# finish vertex 57
# [57]
# finish candidates_order [57]
# finish vertex 60
# [60]
# finish candidates_order [60]
# finish vertex 70
# [100, 77, 112, 70]
# [100, 77, 112, 70]
# [100, 77, 112, 70]
# [100, 77, 112, 70]
# finish candidates_order [100, 77, 112, 70]
# finish vertex 80
# start vertex 92 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates {80, 83}
# clique 13 {82, 92, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [77, 100, 71]
# start used_candidates {80, 83}
# start vertex 77 on order [77, 100, 71] with used_candidates {80, 83}
# clique 14 {77, 82, 92, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57]
# start used_candidates {80, 83}
# start vertex 57 on order [57] with used_candidates {80, 83}
# clique 15 {57, 77, 82, 92, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {80, 83}
# finish candidates_order []
# finish vertex 57
# [57]
# finish candidates_order [57]
# finish vertex 77
# start vertex 100 on order [77, 100, 71] with used_candidates {77, 80, 83}
# clique 14 {82, 92, 100, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {77, 80, 83}
# finish candidates_order []
# finish vertex 100
# start vertex 71 on order [77, 100, 71] with used_candidates {100, 77, 80, 83}
# clique 14 {71, 82, 92, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {100, 77, 80, 83}
# finish candidates_order []
# finish vertex 71
# [77, 100, 71]
# [77, 100, 71]
# [77, 100, 71]
# finish candidates_order [77, 100, 71]
# finish vertex 92
# start vertex 77 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates {80, 83, 92}
# clique 13 {77, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [71, 112, 70]
# start used_candidates {80, 83, 92}
# start vertex 71 on order [71, 112, 70] with used_candidates {80, 83, 92}
# clique 14 {71, 77, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {80, 83, 92}
# finish candidates_order []
# finish vertex 71
# start vertex 112 on order [71, 112, 70] with used_candidates {71, 80, 83, 92}
# clique 14 {77, 82, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# skipped {2, 68, 5, 7, 74, 14, 79, 20, 23, 25, 26, 27, 29, 30, 34, 51, 52, 125, 54, 55, 56, 57, 60, 61}
# finish vertex 112
# start vertex 70 on order [71, 112, 70] with used_candidates {71, 80, 112, 83, 92}
# clique 14 {70, 77, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {71, 80, 112, 83, 92}
# finish candidates_order []
# finish vertex 70
# [71, 112, 70]
# [71, 112, 70]
# [71, 112, 70]
# finish candidates_order [71, 112, 70]
# finish vertex 77
# start vertex 100 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates {77, 80, 83, 92}
# clique 13 {82, 100, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {77, 80, 83, 92}
# start vertex 60 on order [60] with used_candidates {77, 80, 83, 92}
# clique 14 {60, 82, 100, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57]
# start used_candidates {77, 80, 83, 92}
# start vertex 57 on order [57] with used_candidates {77, 80, 83, 92}
# clique 15 {57, 60, 82, 100, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {77, 80, 83, 92}
# finish candidates_order []
# finish vertex 57
# [57]
# finish candidates_order [57]
# finish vertex 60
# [60]
# finish candidates_order [60]
# finish vertex 100
# start vertex 71 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates {100, 77, 80, 83, 92}
# clique 13 {71, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [112, 70]
# start used_candidates {100, 77, 80, 83, 92}
# start vertex 112 on order [112, 70] with used_candidates {100, 77, 80, 83, 92}
# clique 14 {71, 82, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# skipped {2, 4, 5, 7, 20, 23, 25, 26, 27, 29, 34, 51, 54, 55, 56, 57, 60, 61, 68, 74, 79, 120, 125}
# finish vertex 112
# start vertex 70 on order [112, 70] with used_candidates {100, 77, 80, 112, 83, 92}
# clique 14 {70, 71, 82, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {100, 77, 80, 112, 83, 92}
# finish candidates_order []
# finish vertex 70
# [112, 70]
# [112, 70]
# finish candidates_order [112, 70]
# finish vertex 71
# start vertex 112 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates {100, 71, 77, 80, 83, 92}
# break 112 on order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125]
# finish candidates_order [83, 80, 92, 77, 100, 71, 112, 70, 120, 68, 60, 57, 56, 55, 52, 61, 51, 40, 74, 34, 75, 54, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125]
# finish vertex 82
# start vertex 80 on order [82, 80, 100, 77, 70, 120, 68, 60, 92, 57, 74, 56, 55, 54, 52, 71, 51, 83, 61, 47, 40, 112, 34, 75, 50, 30, 28, 79, 26, 27, 16, 29, 14, 7, 5, 23, 25, 4, 2, 20, 125] with used_candidates {82}
# clique 12 {80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [77, 70, 120, 68]
# start used_candidates {82}
# start vertex 77 on order [77, 70, 120, 68] with used_candidates {82}
# clique 13 {77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [79, 112, 70, 68]
# start used_candidates {82}
# start vertex 79 on order [79, 112, 70, 68] with used_candidates {82}
# clique 14 {77, 79, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {82}
# start vertex 60 on order [60] with used_candidates {82}
# clique 15 {60, 77, 79, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57]
# start used_candidates {82}
# start vertex 57 on order [57] with used_candidates {82}
# clique 16 {57, 60, 77, 79, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55]
# start used_candidates {82}
# start vertex 56 on order [56, 55] with used_candidates {82}
# clique 17 {56, 57, 60, 77, 79, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {82}
# finish candidates_order []
# finish vertex 56
# start vertex 55 on order [56, 55] with used_candidates {82, 56}
# clique 17 {55, 57, 60, 77, 79, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {82, 56}
# finish candidates_order []
# finish vertex 55
# [56, 55]
# [56, 55]
# finish candidates_order [56, 55]
# finish vertex 57
# [57]
# finish candidates_order [57]
# finish vertex 60
# [60]
# finish candidates_order [60]
# finish vertex 79
# start vertex 112 on order [79, 112, 70, 68] with used_candidates {79, 82}
# clique 14 {77, 80, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {79, 82}
# start vertex 60 on order [60] with used_candidates {79, 82}
# clique 15 {60, 77, 80, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57]
# start used_candidates {79, 82}
# start vertex 57 on order [57] with used_candidates {79, 82}
# clique 16 {57, 60, 77, 80, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55]
# start used_candidates {79, 82}
# start vertex 56 on order [56, 55] with used_candidates {79, 82}
# clique 17 {56, 57, 60, 77, 80, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82}
# finish candidates_order []
# finish vertex 56
# start vertex 55 on order [56, 55] with used_candidates {79, 82, 56}
# clique 17 {55, 57, 60, 77, 80, 104, 109, 110, 111, 112, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 56}
# finish candidates_order []
# finish vertex 55
# [56, 55]
# [56, 55]
# finish candidates_order [56, 55]
# finish vertex 57
# [57]
# finish candidates_order [57]
# finish vertex 60
# [60]
# finish candidates_order [60]
# finish vertex 112
# start vertex 70 on order [79, 112, 70, 68] with used_candidates {79, 82, 112}
# clique 14 {70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60, 57]
# start used_candidates {79, 82, 112}
# start vertex 60 on order [60, 57] with used_candidates {79, 82, 112}
# clique 15 {60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57, 56, 55]
# start used_candidates {79, 82, 112}
# start vertex 57 on order [57, 56, 55] with used_candidates {79, 82, 112}
# clique 16 {57, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55, 54]
# start used_candidates {79, 82, 112}
# start vertex 56 on order [56, 55, 54] with used_candidates {79, 82, 112}
# clique 17 {56, 57, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [54]
# start used_candidates {79, 82, 112}
# start vertex 54 on order [54] with used_candidates {79, 82, 112}
# clique 18 {54, 56, 57, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [52]
# start used_candidates {79, 82, 112}
# start vertex 52 on order [52] with used_candidates {79, 82, 112}
# clique 19 {52, 54, 56, 57, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112}
# finish candidates_order []
# finish vertex 52
# [52]
# finish candidates_order [52]
# finish vertex 54
# [54]
# finish candidates_order [54]
# finish vertex 56
# start vertex 55 on order [56, 55, 54] with used_candidates {79, 82, 112, 56}
# clique 17 {55, 57, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [71]
# start used_candidates {79, 82, 112, 56}
# start vertex 71 on order [71] with used_candidates {79, 82, 112, 56}
# clique 18 {55, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [26]
# start used_candidates {79, 82, 112, 56}
# start vertex 26 on order [26] with used_candidates {79, 82, 112, 56}
# clique 19 {26, 55, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [25, 28]
# start used_candidates {79, 82, 112, 56}
# start vertex 25 on order [25, 28] with used_candidates {79, 82, 112, 56}
# clique 20 {26, 25, 55, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [54]
# start used_candidates {79, 82, 112, 56}
# start vertex 54 on order [54] with used_candidates {79, 82, 112, 56}
# clique 21 {26, 25, 54, 55, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [29]
# start used_candidates {79, 82, 112, 56}
# start vertex 29 on order [29] with used_candidates {79, 82, 112, 56}
# clique 22 {26, 25, 29, 54, 55, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112, 56}
# finish candidates_order []
# finish vertex 29
# [29]
# finish candidates_order [29]
# finish vertex 54
# [54]
# finish candidates_order [54]
# finish vertex 25
# start vertex 28 on order [25, 28] with used_candidates {79, 82, 112, 56, 25}
# clique 20 {26, 28, 55, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112, 56, 25}
# finish candidates_order []
# finish vertex 28
# [25, 28]
# [25, 28]
# finish candidates_order [25, 28]
# finish vertex 26
# [26]
# finish candidates_order [26]
# finish vertex 71
# [71]
# finish candidates_order [71]
# finish vertex 55
# start vertex 54 on order [56, 55, 54] with used_candidates {79, 82, 112, 55, 56}
# clique 17 {54, 57, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [71]
# start used_candidates {79, 82, 112, 55, 56}
# start vertex 71 on order [71] with used_candidates {79, 82, 112, 55, 56}
# clique 18 {54, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [26]
# start used_candidates {79, 82, 112, 55, 56}
# start vertex 26 on order [26] with used_candidates {79, 82, 112, 55, 56}
# clique 19 {26, 54, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [25, 28]
# start used_candidates {79, 82, 112, 55, 56}
# start vertex 25 on order [25, 28] with used_candidates {79, 82, 112, 55, 56}
# clique 20 {25, 26, 54, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [29]
# start used_candidates {79, 82, 112, 55, 56}
# start vertex 29 on order [29] with used_candidates {79, 82, 112, 55, 56}
# clique 21 {25, 26, 29, 54, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112, 55, 56}
# finish candidates_order []
# finish vertex 29
# [29]
# finish candidates_order [29]
# finish vertex 25
# start vertex 28 on order [25, 28] with used_candidates {79, 82, 112, 55, 56, 25}
# clique 20 {26, 28, 54, 57, 60, 70, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112, 55, 56, 25}
# finish candidates_order []
# finish vertex 28
# [25, 28]
# [25, 28]
# finish candidates_order [25, 28]
# finish vertex 26
# [26]
# finish candidates_order [26]
# finish vertex 71
# [71]
# finish candidates_order [71]
# finish vertex 54
# [56, 55, 54]
# [56, 55, 54]
# [56, 55, 54]
# finish candidates_order [56, 55, 54]
# finish vertex 57
# start vertex 56 on order [57, 56, 55] with used_candidates {79, 82, 112, 57}
# clique 16 {56, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112, 57}
# finish candidates_order []
# finish vertex 56
# start vertex 55 on order [57, 56, 55] with used_candidates {79, 82, 112, 57, 56}
# clique 16 {55, 60, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112, 57, 56}
# finish candidates_order []
# finish vertex 55
# [57, 56, 55]
# [57, 56, 55]
# [57, 56, 55]
# finish candidates_order [57, 56, 55]
# finish vertex 60
# start vertex 57 on order [60, 57] with used_candidates {79, 82, 112, 60}
# clique 15 {57, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55]
# start used_candidates {79, 82, 112, 60}
# start vertex 56 on order [56, 55] with used_candidates {79, 82, 112, 60}
# clique 16 {56, 57, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# skipped {5, 7, 14, 25, 28, 29, 30, 34, 40, 47, 50, 51, 52, 54, 68, 71, 75, 83, 125}
# finish vertex 56
# start vertex 55 on order [56, 55] with used_candidates {79, 82, 112, 60, 56}
# clique 16 {55, 57, 70, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {79, 82, 112, 60, 56}
# finish candidates_order []
# finish vertex 55
# [56, 55]
# [56, 55]
# finish candidates_order [56, 55]
# finish vertex 57
# [60, 57]
# [60, 57]
# finish candidates_order [60, 57]
# finish vertex 70
# start vertex 68 on order [79, 112, 70, 68] with used_candidates {70, 79, 82, 112}
# clique 14 {68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60, 57]
# start used_candidates {70, 79, 82, 112}
# start vertex 60 on order [60, 57] with used_candidates {70, 79, 82, 112}
# clique 15 {60, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57, 56, 55]
# start used_candidates {70, 79, 82, 112}
# start vertex 57 on order [57, 56, 55] with used_candidates {70, 79, 82, 112}
# clique 16 {57, 60, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55, 54]
# start used_candidates {70, 79, 82, 112}
# start vertex 56 on order [56, 55, 54] with used_candidates {70, 79, 82, 112}
# clique 17 {56, 57, 60, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {70, 79, 82, 112}
# finish candidates_order []
# finish vertex 56
# start vertex 55 on order [56, 55, 54] with used_candidates {70, 79, 82, 112, 56}
# clique 17 {55, 57, 60, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [71]
# start used_candidates {70, 79, 82, 112, 56}
# start vertex 71 on order [71] with used_candidates {70, 79, 82, 112, 56}
# clique 18 {55, 57, 60, 68, 71, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {70, 79, 82, 112, 56}
# finish candidates_order []
# finish vertex 71
# [71]
# finish candidates_order [71]
# finish vertex 55
# start vertex 54 on order [56, 55, 54] with used_candidates {70, 79, 112, 82, 55, 56}
# clique 17 {54, 57, 60, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {70, 79, 112, 82, 55, 56}
# finish candidates_order []
# finish vertex 54
# [56, 55, 54]
# [56, 55, 54]
# [56, 55, 54]
# finish candidates_order [56, 55, 54]
# finish vertex 57
# start vertex 56 on order [57, 56, 55] with used_candidates {70, 79, 112, 82, 57}
# clique 16 {56, 60, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# skipped {5, 7, 14, 20, 23, 25, 27, 28, 29, 34, 40, 47, 50, 51, 52, 54, 71, 74, 75, 83, 125}
# finish vertex 56
# start vertex 55 on order [57, 56, 55] with used_candidates {70, 79, 112, 82, 56, 57}
# clique 16 {55, 60, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {70, 79, 112, 82, 56, 57}
# finish candidates_order []
# finish vertex 55
# [57, 56, 55]
# [57, 56, 55]
# [57, 56, 55]
# finish candidates_order [57, 56, 55]
# finish vertex 60
# start vertex 57 on order [60, 57] with used_candidates {70, 79, 112, 82, 60}
# clique 15 {57, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56, 55]
# start used_candidates {70, 79, 112, 82, 60}
# start vertex 56 on order [56, 55] with used_candidates {70, 79, 112, 82, 60}
# clique 16 {56, 57, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# skipped {5, 7, 14, 20, 23, 25, 28, 29, 34, 40, 47, 50, 51, 52, 54, 71, 75, 83, 125}
# finish vertex 56
# start vertex 55 on order [56, 55] with used_candidates {70, 79, 112, 82, 56, 60}
# clique 16 {55, 57, 68, 77, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {70, 79, 112, 82, 56, 60}
# finish candidates_order []
# finish vertex 55
# [56, 55]
# [56, 55]
# finish candidates_order [56, 55]
# finish vertex 57
# [60, 57]
# [60, 57]
# finish candidates_order [60, 57]
# finish vertex 68
# [79, 112, 70, 68]
# [79, 112, 70, 68]
# [79, 112, 70, 68]
# [79, 112, 70, 68]
# finish candidates_order [79, 112, 70, 68]
# finish vertex 77
# start vertex 70 on order [77, 70, 120, 68] with used_candidates {77, 82}
# clique 13 {70, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [100, 71]
# start used_candidates {77, 82}
# start vertex 100 on order [100, 71] with used_candidates {77, 82}
# clique 14 {70, 80, 100, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order []
# start used_candidates {77, 82}
# finish candidates_order []
# finish vertex 100
# start vertex 71 on order [100, 71] with used_candidates {100, 77, 82}
# clique 14 {71, 70, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {100, 77, 82}
# start vertex 60 on order [60] with used_candidates {100, 77, 82}
# clique 15 {60, 71, 70, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [57]
# start used_candidates {100, 77, 82}
# start vertex 57 on order [57] with used_candidates {100, 77, 82}
# clique 16 {57, 60, 71, 70, 80, 104, 109, 110, 111, 114, 115, 117, 121, 122, 123, 124}
# start candidates_order [56]
# start used_candidates {100, 77, 82}
# start vertex 56 on order [56] with used_candidates {100, 77, 82}
# ...
# finish vertex 121
# start vertex 110 on order [121, 110, 104, 101, 99, 109, 93, 89, 82, 80, 92, 120, 77, 74, 88, 71, 68, 78, 61, 79, 60, 56, 55, 54, 49, 100, 69, 48, 51, 103, 83, 46, 47, 43, 70, 34, 75, 50, 30, 112, 28, 38, 26, 52, 57, 18, 27, 16, 25, 21, 10, 29, 8, 40, 14, 7, 5, 23, 4, 22, 2, 20, 1, 37, 125] with used_candidates {121}
# clique 8 {111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [120, 104, 101, 99, 109, 93, 89, 82, 80, 92, 100, 77]
# start used_candidates {121}
# start vertex 120 on order [120, 104, 101, 99, 109, 93, 89, 82, 80, 92, 100, 77] with used_candidates {121}
# clique 9 {120, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [104, 101, 109, 93, 89, 82]
# start used_candidates {121}
# start vertex 104 on order [104, 101, 109, 93, 89, 82] with used_candidates {121}
# clique 10 {120, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [109, 103, 93, 89, 82]
# start used_candidates {121}
# start vertex 109 on order [109, 103, 93, 89, 82] with used_candidates {121}
# clique 11 {120, 104, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [89, 82]
# start used_candidates {121}
# start vertex 89 on order [89, 82] with used_candidates {121}
# clique 12 {89, 120, 104, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {121}
# finish candidates_order []
# finish vertex 89
# start vertex 82 on order [89, 82] with used_candidates {89, 121}
# clique 12 {82, 120, 104, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {89, 121}
# finish candidates_order []
# finish vertex 82
# [89, 82]
# [89, 82]
# finish candidates_order [89, 82]
# finish vertex 109
# start vertex 103 on order [109, 103, 93, 89, 82] with used_candidates {109, 121}
# clique 11 {120, 103, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [99]
# start used_candidates {109, 121}
# start vertex 99 on order [99] with used_candidates {109, 121}
# clique 12 {120, 99, 103, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [93]
# start used_candidates {109, 121}
# start vertex 93 on order [93] with used_candidates {109, 121}
# clique 13 {120, 93, 99, 103, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# skipped {1, 5, 70, 7, 10, 74, 78, 79, 80, 20, 22, 23, 25, 26, 89, 28, 29, 30, 34, 100, 40, 112, 49, 52, 54, 60, 125}
# finish vertex 93
# [93]
# finish candidates_order [93]
# finish vertex 99
# [99]
# finish candidates_order [99]
# finish vertex 103
# start vertex 93 on order [109, 103, 93, 89, 82] with used_candidates {103, 109, 121}
# clique 11 {120, 93, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [99, 89, 82]
# start used_candidates {103, 109, 121}
# start vertex 99 on order [99, 89, 82] with used_candidates {103, 109, 121}
# clique 12 {120, 93, 99, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [89]
# start used_candidates {103, 109, 121}
# start vertex 89 on order [89] with used_candidates {103, 109, 121}
# clique 13 {89, 120, 93, 99, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {103, 109, 121}
# finish candidates_order []
# finish vertex 89
# [89]
# finish candidates_order [89]
# finish vertex 99
# start vertex 89 on order [99, 89, 82] with used_candidates {99, 103, 109, 121}
# clique 12 {89, 120, 93, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {99, 103, 109, 121}
# finish candidates_order []
# finish vertex 89
# start vertex 82 on order [99, 89, 82] with used_candidates {89, 99, 103, 109, 121}
# clique 12 {82, 120, 93, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {89, 99, 103, 109, 121}
# finish candidates_order []
# finish vertex 82
# [99, 89, 82]
# [99, 89, 82]
# [99, 89, 82]
# finish candidates_order [99, 89, 82]
# finish vertex 93
# start vertex 89 on order [109, 103, 93, 89, 82] with used_candidates {93, 103, 109, 121}
# clique 11 {89, 120, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {93, 103, 109, 121}
# finish candidates_order []
# finish vertex 89
# start vertex 82 on order [109, 103, 93, 89, 82] with used_candidates {89, 93, 103, 109, 121}
# clique 11 {82, 120, 104, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {89, 93, 103, 109, 121}
# finish candidates_order []
# finish vertex 82
# [109, 103, 93, 89, 82]
# [109, 103, 93, 89, 82]
# [109, 103, 93, 89, 82]
# [109, 103, 93, 89, 82]
# [109, 103, 93, 89, 82]
# finish candidates_order [109, 103, 93, 89, 82]
# finish vertex 104
# start vertex 101 on order [104, 101, 109, 93, 89, 82] with used_candidates {104, 121}
# clique 10 {120, 101, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [109, 93, 89, 82, 80]
# start used_candidates {104, 121}
# start vertex 109 on order [109, 93, 89, 82, 80] with used_candidates {104, 121}
# clique 11 {120, 101, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [89, 82]
# start used_candidates {104, 121}
# start vertex 89 on order [89, 82] with used_candidates {104, 121}
# clique 12 {89, 120, 101, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [80]
# start used_candidates {104, 121}
# start vertex 80 on order [80] with used_candidates {104, 121}
# clique 13 {80, 89, 120, 101, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [79]
# start used_candidates {104, 121}
# start vertex 79 on order [79] with used_candidates {104, 121}
# clique 14 {79, 80, 89, 120, 101, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {104, 121}
# finish candidates_order []
# finish vertex 79
# [79]
# finish candidates_order [79]
# finish vertex 80
# [80]
# finish candidates_order [80]
# finish vertex 89
# start vertex 82 on order [89, 82] with used_candidates {89, 104, 121}
# clique 12 {82, 120, 101, 109, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order []
# start used_candidates {89, 104, 121}
# finish candidates_order []
# finish vertex 82
# [89, 82]
# [89, 82]
# finish candidates_order [89, 82]
# finish vertex 109
# start vertex 93 on order [109, 93, 89, 82, 80] with used_candidates {104, 109, 121}
# clique 11 {120, 93, 101, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [89, 82, 80]
# start used_candidates {104, 109, 121}
# start vertex 89 on order [89, 82, 80] with used_candidates {104, 109, 121}
# clique 12 {89, 120, 93, 101, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [80, 79]
# start used_candidates {104, 109, 121}
# start vertex 80 on order [80, 79] with used_candidates {104, 109, 121}
# clique 13 {80, 89, 120, 93, 101, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [79, 78]
# start used_candidates {104, 109, 121}
# start vertex 79 on order [79, 78] with used_candidates {104, 109, 121}
# clique 14 {79, 80, 89, 120, 93, 101, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [99, 78]
# start used_candidates {104, 109, 121}
# start vertex 99 on order [99, 78] with used_candidates {104, 109, 121}
# clique 15 {79, 80, 89, 120, 93, 99, 101, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [60]
# start used_candidates {104, 109, 121}
# start vertex 60 on order [60] with used_candidates {104, 109, 121}
# clique 16 {60, 79, 80, 89, 120, 93, 99, 101, 111, 110, 114, 115, 117, 122, 123, 124}
# start candidates_order [54]
# start used_candidates {104, 109, 121}
# start vertex 54 on order [54]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-852-0fe2787d0001> in <module>
#       3 used_candidates = set()
#       4 len_max_current_clique = 1
# ----> 5 branching_new(candidates,used_candidates)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      38         candidates_br = update_candidates(used_candidates, candidates, vertex_to_clique = vertex)
#      39 #         print('candidates_br',candidates_br)
# ---> 40         branching_new(candidates_br, used_candidates)
#      41         used_candidates.add(vertex)
#      42         clique.remove(vertex)
#
# <ipython-input-850-6162cf7e1143> in branching_new(candidates, used_candidates)
#      24     print('start used_candidates', used_candidates)
#      25     for vertex in candidates_order:
# ---> 26         print('start vertex',vertex, 'on order',candidates_order, 'with used_candidates',used_candidates  )
#      27         vertex_color = vertex_coloring[vertex]
#      28         if (vertex_color + 1) + len(clique) <= len_max_current_clique: # len_max_current_clique может измениться. Поэтому проверяем
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     393                                  copy_threshold=self.copy_threshold)
#     394             data.group = group
# --> 395         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     396
#     397     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
for i in range(7):
    print(i)
    if i> 3:
        break
else:
    print(228)
# Out:
# 0
# 1
# 2
# 3
# 4
